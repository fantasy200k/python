# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
plt.plot([3,4,6],[8,10,14])

# %%
x=[3,4,6]
y=[8,10,14]
plt.plot(x,y)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income by Age')
plt.show()

# %%
x=[3,4,6]
y=[8,10,14]
plt.bar(x,y)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income by Age')
plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
income = [5,15,20,18,12,8,5]
bin = [5,10,20,30]
plt.hist(income,bin)
# Out:
# (array([3., 3., 1.]), array([ 5, 10, 20, 30]), <a list of 3 Patch objects>)

# %%
mktg = pd.read_csv("/home/nbuser/retailMarketing29jun.csv",sep=',')
mktg.head()
# Out:
#    Customer  Age  Gender  Own Home  Married  Close    Salary  Children  \
# 0         1   73       0         0        0      1   16400.0         1
# 1         2   22       0         1        1      0  108100.0         3
# 2         3   51       1         1        1      1   97300.0         1
# 3         4   48       1         1        1      1   26800.0         0
# 4         5   57       1         0        0      1   11200.0         0
#
#    PrevCust  PrevSpent  Catalogs  AmountSpent
# 0         1      246.0        12        218.0
# 1         1     1622.0        18       2632.0
# 2         0        0.0        12       3048.0
# 3         1      536.0        12        435.0
# 4         0        0.0         6        106.0

# %%
mktg.columns
# Out:
# Index(['Customer', 'Age', 'Gender', 'Own Home', 'Married', 'Close', 'Salary',
#        'Children', 'PrevCust', 'PrevSpent', 'Catalogs', 'AmountSpent'],
#       dtype='object')

# %%
mktg.dtypes
# Out:
# Customer         int64
# Age              int64
# Gender           int64
# Own Home         int64
# Married          int64
# Close            int64
# Salary         float64
# Children         int64
# PrevCust         int64
# PrevSpent      float64
# Catalogs         int64
# AmountSpent    float64
# dtype: object

# %%
plt.hist(mktg['AmountSpent'],bins=10)
# Out:
# (array([85., 62., 43., 25., 19., 10.,  3.,  2.,  0.,  1.]),
#  array([  47. ,  598.7, 1150.4, 1702.1, 2253.8, 2805.5, 3357.2, 3908.9,
#         4460.6, 5012.3, 5564. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## bivariate Analysis - categorical with quantiative variable

# %%
sns.boxplot(mktg['Own Home'], mktg['AmountSpent'])

# %% [markdown]
# ## bivariate Analysis - finding the relationship between quantiative  with quantiative variable

# %%
sns.scatterplot(mktg['Salary'], mktg['AmountSpent'])

# %%
mktg['AmountSpent'].mean()
# Out:
# 1184.036

# %%
sns.boxplot(mktg['Own Home'], mktg['Salary'])

# %%
sns.boxplot(mktg['Own Home'], mktg['AmountSpent'],hue=mktg['Gender'])

# %%
sns.boxplot(mktg['Own Home'], mktg['AmountSpent'],hue=mktg['Married'])

# %%
sns.boxplot(mktg['Own Home'], mktg['AmountSpent'],hue=mktg['Children'])

# %%
sns.stripplot(mktg['Own Home'],mktg['Salary'],hue=mktg['Gender'])

# %%
sns.stripplot(mktg['Own Home'],mktg['Salary'],hue=mktg['Gender'],jitter=True)

# %%
sns.swarmplot(mktg['Own Home'],mktg['Salary'],hue=mktg['Gender'])

# %%
sns.countplot(x='Catalogs',data=mktg)

# %%
sns.boxplot(mktg['Own Home'], mktg['AmountSpent'],hue=mktg['Catalogs'])

# %%
q = sns.factorplot(x='Catalogs',y='AmountSpent',data=mktg,hue='Own Home',col='Own Home',kind='swarm')

# %%
q.set_xticklabels(rotation=-45)

# %%
sns.distplot(mktg.AmountSpent)

# %% [markdown]
# ## bivariate analysis

# %%
sns.jointplot(mktg.AmountSpent,mktg.Salary)

# %%
corr = mktg.corr()
sns.heatmap(corr,annot=True)

# %%
sns.violinplot(mktg['Own Home'],mktg['AmountSpent'])

# %%
aggMkt = mktg.groupby('Catalogs').AmountSpent.sum()

# %%
g = sns.FacetGrid(mktg,col="Catalogs")
g.map(sns.barplot,"AmountSpent",orient='v')

# %%
sns.barplot
