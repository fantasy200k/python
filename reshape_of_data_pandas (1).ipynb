# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/dat1/warranty.csv",sep=',', encoding= 'ISO-8859-1')
df
# Out:
#        Row ID         Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878    2/5/2013    2/7/2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320   11/5/2013   11/6/2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366   6/19/2014   6/19/2014        Same Day
# 51286   35398   US-2014-102288   6/20/2014   6/24/2014  Standard Class
# 51287   40470   US-2013-155768   12/2/2013   12/2/2013        Same Day
# 51288    9596   MX-2012-140767   2/18/2012   2/22/2012  Standard Class
# 51289    6147   MX-2012-134460   5/22/2012   5/26/2012    Second Class
#
#       Customer_ID     Customer Name      Segment           City  \
# ...

# %%
df.head()
# Out:
#    Row ID         Order_ID  Order_Date   Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878    2/5/2013    2/7/2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320   11/5/2013   11/6/2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.dtypes
# Out:
# Row ID              int64
# Order_ID           object
# Order_Date         object
# Ship_Date          object
# Ship_Mode          object
# Customer_ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping_Cost     float64
# Order_Priority     object
# Return             object
# Returned            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Row ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order_Priority', 'Return', 'Returned'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping_Cost      Returned
# count  51290.000000   51290.000000  51290.000000
# mean      28.610982      26.375915      0.059466
# std      174.340972      57.296804      0.236497
# min    -6599.978000       0.000000      0.000000
# ...

# %%
df[['Country','Product Name','Category']]
# Out:
#              Country                                       Product Name  \
# 0      United States  Plantronics CS510 - Over-the-Head monaural Wir...
# 1          Australia          Novimex Executive Leather Armchair, Black
# 2          Australia                  Nokia Smart Phone, with Caller ID
# 3            Germany                     Motorola Smart Phone, Cordless
# 4            Senegal                     Sharp Wireless Fax, High-Speed
# ...              ...                                                ...
# 51285          Japan                      Advantus Thumb Tacks, 12 Pack
# 51286  United States  Hoover Replacement Belt for Commercial Guardsm...
# 51287  United States       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes
# 51288         Brazil                            Acco Index Tab, Economy
# 51289      Nicaragua            Eaton Computer Printout Paper, 8.5 x 11
#
#               Category
# 0           Technology
# 1            Furniture
# 2           Technology
# ...

# %%
df.groupby( ['Country','Category','Product Name']).agg({"Sales":"sum"})
# Out:
#                                                                         Sales
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled       4626.150
#                        Bush Classic Bookcase, Pine                   2070.150
#                        Chromcraft Coffee Table, with Bottom Storage   267.090
#                        Chromcraft Wood Table, with Bottom Storage    1447.560
#                        Deflect-O Clock, Durable                        94.680
# ...                                                                       ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                     101.754
#                        Okidata Calculator, Red                         14.832
#                        Panasonic Card Printer, Durable                104.364
#                        Samsung Headset, with Caller ID                 21.960
#                        StarTech Phone, Red                             21.501
#
# ...

# %%
4626.150/2
# Out:
# 2313.075

# %%
pd.pivot_table(df,index=['Category'])
# Out:
#                  Discount   Postal Code     Profit  Quantity  Returned  \
# Category
# Furniture        0.168087  55726.556341  28.878567  3.539287  0.064601
# Office Supplies  0.137409  54890.951211  16.578961  3.459278  0.057174
# Technology       0.135342  55551.572279  65.454958  3.468691  0.061532
#
#                        Row ID       Sales  Shipping_Cost
# Category
# Furniture        24451.996760  416.248905      44.584919
# Office Supplies  26073.185304  121.097120      12.964899
# Technology       25488.911449  467.858939      49.999876

# %%
pd.pivot_table(df,index=['Country'])
# Out:
#              Discount  Postal Code      Profit  Quantity  Returned  \
# Country
# Afghanistan  0.000000          NaN   99.278182  4.145455  0.054545
# Albania      0.000000          NaN   44.332500  2.500000  0.000000
# Algeria      0.000000          NaN   46.461735  2.316327  0.000000
# Angola       0.000000          NaN   53.237459  2.598361  0.000000
# Argentina    0.433210          NaN  -47.932812  3.856410  0.053846
# ...               ...          ...         ...       ...       ...
# Venezuela    0.409412          NaN  -57.849023  3.989691  0.067010
# Vietnam      0.239434          NaN   -7.057474  3.758491  0.026415
# Yemen        0.700000          NaN -123.548600  2.366667  0.000000
# Zambia       0.000000          NaN   68.644412  2.460784  0.000000
# Zimbabwe     0.700000          NaN  -67.859812  2.375000  0.000000
#
#                    Row ID       Sales  Shipping_Cost
# Country
# Afghanistan  26301.927273  394.060364      41.822364
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'])
# Out:
#                                                                      Discount  \
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled            0.0
#                        Bush Classic Bookcase, Pine                        0.0
#                        Chromcraft Coffee Table, with Bottom Storage       0.0
#                        Chromcraft Wood Table, with Bottom Storage         0.0
#                        Deflect-O Clock, Durable                           0.0
# ...                                                                       ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                         0.7
#                        Okidata Calculator, Red                            0.7
#                        Panasonic Card Printer, Durable                    0.7
#                        Samsung Headset, with Caller ID                    0.7
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'],values=['Sales'], fill_value=0)
# Out:
#                                                                         Sales
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled       4626.150
#                        Bush Classic Bookcase, Pine                   2070.150
#                        Chromcraft Coffee Table, with Bottom Storage   267.090
#                        Chromcraft Wood Table, with Bottom Storage    1447.560
#                        Deflect-O Clock, Durable                        94.680
# ...                                                                       ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                     101.754
#                        Okidata Calculator, Red                         14.832
#                        Panasonic Card Printer, Durable                104.364
#                        Samsung Headset, with Caller ID                 21.960
#                        StarTech Phone, Red                             21.501
#
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'],values=['Quantity','Sales'], fill_value=0)
# Out:
#                                                                      Quantity  \
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled            5.0
#                        Bush Classic Bookcase, Pine                        5.0
#                        Chromcraft Coffee Table, with Bottom Storage       1.0
#                        Chromcraft Wood Table, with Bottom Storage         3.0
#                        Deflect-O Clock, Durable                           2.0
# ...                                                                       ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                         2.0
#                        Okidata Calculator, Red                            1.0
#                        Panasonic Card Printer, Durable                    2.0
#                        Samsung Headset, with Caller ID                    1.0
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'],values=['Quantity','Sales'], aggfunc=[np.sum],fill_value=0)
# Out:
#                                                                          sum  \
#                                                                     Quantity
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled             5
#                        Bush Classic Bookcase, Pine                         5
#                        Chromcraft Coffee Table, with Bottom Storage        1
#                        Chromcraft Wood Table, with Bottom Storage          3
#                        Deflect-O Clock, Durable                            2
# ...                                                                      ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                          2
#                        Okidata Calculator, Red                             1
#                        Panasonic Card Printer, Durable                     2
#                        Samsung Headset, with Caller ID                     1
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'],values=['Quantity','Sales','Profit'], aggfunc=[np.sum],fill_value=0)
# Out:
#                                                                          sum  \
#                                                                       Profit
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled       647.550
#                        Bush Classic Bookcase, Pine                   848.700
#                        Chromcraft Coffee Table, with Bottom Storage   34.710
#                        Chromcraft Wood Table, with Bottom Storage    564.480
#                        Deflect-O Clock, Durable                        1.860
# ...                                                                      ...
# Zimbabwe    Technology Nokia Audio Dock, Cordless                   -169.626
#                        Okidata Calculator, Red                       -20.298
#                        Panasonic Card Printer, Durable              -173.976
#                        Samsung Headset, with Caller ID               -47.580
# ...

# %%
pd.pivot_table(df,index=['Country','Category','Product Name'],values=['Quantity','Sales','Profit'], aggfunc=[np.sum],fill_value=0, margins=True)
# Out:
#                                                                               sum  \
#                                                                            Profit
# Country     Category   Product Name
# Afghanistan Furniture  Bevis Conference Table, Fully Assembled       6.475500e+02
#                        Bush Classic Bookcase, Pine                   8.487000e+02
#                        Chromcraft Coffee Table, with Bottom Storage  3.471000e+01
#                        Chromcraft Wood Table, with Bottom Storage    5.644800e+02
#                        Deflect-O Clock, Durable                      1.860000e+00
# ...                                                                           ...
# Zimbabwe    Technology Okidata Calculator, Red                      -2.029800e+01
#                        Panasonic Card Printer, Durable              -1.739760e+02
#                        Samsung Headset, with Caller ID              -4.758000e+01
# ...
